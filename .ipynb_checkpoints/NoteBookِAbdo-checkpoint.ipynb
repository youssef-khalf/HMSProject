# %%
import pandas as ps 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
df = ps.read_csv("C:\\Users\\reda\\Downloads\\train.csv (1)\\train.csv")
df.head()
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
# 2  1628180742           2                       8.0          353733
# 3  1628180742           3                      18.0          353733
# 4  1628180742           4                      24.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
# 2                   2                               8.0  1142670488
# 3                   3                              18.0  2718991173
# 4                   4                              24.0  3080632009
#
#    patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  lrda_vote  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0       1628180742           0                       0.0          353733
# 1       1628180742           1                       6.0          353733
# 2       1628180742           2                       8.0          353733
# 3       1628180742           3                      18.0          353733
# 4       1628180742           4                      24.0          353733
# ...            ...         ...                       ...             ...
# 106795   351917269           6                      12.0      2147388374
# 106796   351917269           7                      14.0      2147388374
# 106797   351917269           8                      16.0      2147388374
# 106798   351917269           9                      18.0      2147388374
# 106799   351917269          10                      20.0      2147388374
#
# ...

# %%
df1 = df.drop(columns=['expert_consensus'])

# %%
df1.head()
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
# 2  1628180742           2                       8.0          353733
# 3  1628180742           3                      18.0          353733
# 4  1628180742           4                      24.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
# 2                   2                               8.0  1142670488
# 3                   3                              18.0  2718991173
# 4                   4                              24.0  3080632009
#
#    patient_id  seizure_vote  lpd_vote  gpd_vote  lrda_vote  grda_vote  \
# 0       42516             3         0         0          0          0
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df)
plt.title('Box Plot')
plt.xticks(rotation=45)
plt.grid()
plt.show()
